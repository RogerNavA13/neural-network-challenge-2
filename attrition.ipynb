# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Print unique values in target variables
print("Unique Attrition values:", attrition_df['Attrition'].unique())
print("Unique Department values:", attrition_df['Department'].unique())
# Out:
# Unique Attrition values: ['Yes' 'No']
# Unique Department values: ['Sales' 'Research & Development' 'Human Resources']

# %%
# Create x using selected columns
selected_columns = [
    'Age', 'BusinessTravel', 'DistanceFromHome', 'Education',
    'EducationField', 'EnvironmentSatisfaction', 'JobInvolvement',
    'JobLevel', 'JobSatisfaction', 'YearsSinceLastPromotion']
x = attrition_df[selected_columns].copy()

# Create separate DataFrames for features and targets
y_attrition = attrition_df['Attrition']
y_department = attrition_df['Department']

# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]

# Display the new DataFrame
print(y_df.head())
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Preprocessing x features
categorical_cols = ['BusinessTravel', 'EducationField']
numerical_cols = [col for col in x.columns if col not in categorical_cols]

# Scale numerical features
scaler = StandardScaler()
x[numerical_cols] = scaler.fit_transform(x[numerical_cols])

# One-hot encode categorical features
x = pd.get_dummies(x, columns=categorical_cols, drop_first=True)

# Process target variables
# For Attrition (binary classification)
attrition_encoder = OneHotEncoder(sparse_output=False)
y_attrition = attrition_encoder.fit_transform(attrition_df['Attrition'].values.reshape(-1, 1))
print("Attrition encoded shape:", y_attrition.shape)
print("Attrition categories:", attrition_encoder.categories_)

# For Department (multi-class classification)
department_encoder = OneHotEncoder(sparse_output=False)
y_department = department_encoder.fit_transform(attrition_df['Department'].values.reshape(-1, 1))
print("Department encoded shape:", y_department.shape)
print("Department categories:", department_encoder.categories_)
# Out:
# Attrition encoded shape: (1470, 2)
# Attrition categories: [array(['No', 'Yes'], dtype=object)]
# Department encoded shape: (1470, 3)
# Department categories: [array(['Human Resources', 'Research & Development', 'Sales'], dtype=object)]

# %%
# Split the data
x_train, x_test, y_dept_train, y_dept_test, y_attr_train, y_attr_test = train_test_split(
    x, y_attrition, y_department,
    test_size=0.2,
    random_state=42
)

# Define data
print("\nTraining shapes:")
print("X_train shape:", x_train.shape)
print("y_department_train shape:", y_dept_train.shape)
print("y_attrition_train shape:", y_attr_train.shape)
# Out:
# Training shapes:
# X_train shape: (1176, 15)
# y_department_train shape: (1176, 2)
# y_attrition_train shape: (1176, 3)

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Build the model
input_dim = x_train.shape[1]
inputs = layers.Input(shape=(input_dim,))

# Shared layers
x = layers.Dense(64, activation='relu')(inputs)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Department branch and hidden layers
dept_branch = layers.Dense(16, activation='relu')(x)
dept_output = layers.Dense(3, activation='softmax', name='department')(dept_branch)

# Attrition branch and hidden layers
attr_branch = layers.Dense(16, activation='relu')(x)
attr_output = layers.Dense(2, activation='softmax', name='attrition')(attr_branch)

# %%
# Create the model
model = tf.keras.Model(inputs=inputs, outputs=[dept_output, attr_output])

# Compile the model
model.compile(
    optimizer='adam',
    loss={
        'department': 'categorical_crossentropy',
        'attrition': 'categorical_crossentropy'  # Use categorical_crossentropy
    },
    metrics={
        'department': 'accuracy',
        'attrition': 'accuracy'
    }
)

# Summarize the model
print("\nModel Summary:")
model.summary()
# Out:
# Model Summary:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_19            │ (None, 15)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_76 (Dense)          │ (None, 64)             │          1,024 │ input_layer_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_38 (Dropout)      │ (None, 64)             │              0 │ dense_76[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_77 (Dense)          │ (None, 32)             │          2,080 │ dropout_38[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_39 (Dropout)      │ (None, 32)             │              0 │ dense_77[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_78 (Dense)          │ (None, 16)             │            528 │ dropout_39[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_79 (Dense)          │ (None, 16)             │            528 │ dropout_39[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department (Dense)        │ (None, 3)              │             51 │ dense_78[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition (Dense)         │ (None, 2)              │             34 │ dense_79[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,245 (16.58 KB)
#  Trainable params: 4,245 (16.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
- val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4780 - val_department_accuracy: 0.1525 - val_department_loss: 0.6104 - val_loss: 1.1252
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_accuracy: 0.0496 - attrition_loss: 0.4360 - department_accuracy: 0.1510 - department_loss: 0.6696 - loss: 1.1055 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4732 - val_department_accuracy: 0.1525 - val_department_loss: 0.6014 - val_loss: 1.1110
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_accuracy: 0.0333 - attrition_loss: 0.4250 - department_accuracy: 0.1447 - department_loss: 0.5976 - loss: 1.0222 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4686 - val_department_accuracy: 0.1525 - val_department_loss: 0.5956 - val_loss: 1.0997
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_accuracy: 0.0317 - attrition_loss: 0.3899 - department_accuracy: 0.1314 - department_loss: 0.5841 - loss: 0.9740 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4666 - val_department_accuracy: 0.1525 - val_department_loss: 0.5966 - val_loss: 1.0958
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_accuracy: 0.0370 - attrition_loss: 0.3828 - department_accuracy: 0.1125 - department_loss: 0.5957 - loss: 0.9786 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4685 - val_department_accuracy: 0.1525 - val_department_loss: 0.5917 - val_loss: 1.0937
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_accuracy: 0.0420 - attrition_loss: 0.3961 - department_accuracy: 0.1448 - department_loss: 0.6216 - loss: 1.0183 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4654 - val_department_accuracy: 0.1525 - val_department_loss: 0.5879 - val_loss: 1.0876
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_accuracy: 0.0457 - attrition_loss: 0.3914 - department_accuracy: 0.1450 - department_loss: 0.6351 - loss: 1.0265 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4672 - val_department_accuracy: 0.1525 - val_department_loss: 0.5863 - val_loss: 1.0902
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_accuracy: 0.0388 - attrition_loss: 0.3840 - department_accuracy: 0.1406 - department_loss: 0.5954 - loss: 0.9792 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4626 - val_department_accuracy: 0.1525 - val_department_loss: 0.5863 - val_loss: 1.0844
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_accuracy: 0.0387 - attrition_loss: 0.4364 - department_accuracy: 0.1631 - department_loss: 0.5985 - loss: 1.0350 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4644 - val_department_accuracy: 0.1525 - val_department_loss: 0.5887 - val_loss: 1.0885
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_accuracy: 0.0404 - attrition_loss: 0.3839 - department_accuracy: 0.1385 - department_loss: 0.5953 - loss: 0.9791 - val_attrition_accuracy: 0.0424 - val_attrition_loss: 0.4693 - val_department_accuracy: 0.1525 - val_department_loss: 0.5851 - val_loss: 1.0905
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_accuracy: 0.0451 - attrition_loss: 0.4205 - department_accuracy: 0.1477 - department_loss: 0.5963 - loss: 1.0168 - val_attrition_accuracy: 0.0466 - val_attrition_loss: 0.4682 - val_department_accuracy: 0.1525 - val_department_loss: 0.5837 - val_loss: 1.0875
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_accuracy: 0.0433 - attrition_loss: 0.3804 - department_accuracy: 0.1393 - department_loss: 0.6090 - loss: 0.9895 - val_attrition_accuracy: 0.0466 - val_attrition_loss: 0.4748 - val_department_accuracy: 0.1525 - val_department_loss: 0.5827 - val_loss: 1.0962
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_accuracy: 0.0569 - attrition_loss: 0.4105 - department_accuracy: 0.1394 - department_loss: 0.6026 - loss: 1.0131 - val_attrition_accuracy: 0.0551 - val_attrition_loss: 0.4690 - val_department_accuracy: 0.1525 - val_department_loss: 0.5816 - val_loss: 1.0898

# %%
# Evaluate the model with the testing data
# Evaluate the model
test_results = model.evaluate(
    x_test,
    {
        'department': y_dept_test,
        'attrition': y_attr_test
    },
    verbose=0
)

# %%
# Print the accuracy for both department and attrition
print("\nTest Results:")
print(f"Department Accuracy: {test_results[3]:.4f}")
print(f"Attrition Accuracy: {test_results[4]:.4f}")
# Out:
# Test Results:
# Department Accuracy: 0.0408
# Attrition Accuracy: 0.1054

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy is not the best metric. Since the data is imbalanced it can be misleading.
# 2. I chose Softmax. It is a good choice for multi-class problems. It allows the model to predict the class with the best probability.
# 3. Using pre-trained models, applying hyperparameter tuning,incrwasing the number of neurons, and adding more layers.
